// %% [markdown]
// # Lesson B5: Compiler Errors & Debugging
//
// **Duration**: 1.5 hours
// **Stage**: Beginner (Foundations)
//
// ---
//
// ## 🎯 Learning Objectives
//
// By the end of this lesson, you will be able to:
// 1. Interpret and understand Rust compiler error messages
// 2. Use compiler suggestions to fix common mistakes
// 3. Debug Rust programs effectively
// 4. Recognize and fix common beginner errors
// 5. Use println! debugging and dbg! macro
// 6. Understand error recovery strategies

// %% [markdown]
// ## 📋 Prerequisite Review
//
// Quick recap from previous lessons:
// - Variables and mutability
// - Functions and control flow
// - Ownership and borrowing
// - Collections and pattern matching

// %% [markdown]
// ## 🧠 Key Concepts
//
// ### Understanding Rust Compiler Errors
//
// Rust's compiler is your friend! Error messages are detailed and actionable.
//
// **Common Error Categories:**
// 1. **Borrow Checker Errors**: Ownership and borrowing violations
// 2. **Type Errors**: Type mismatches and inference failures
// 3. **Lifetime Errors**: Reference lifetime issues
// 4. **Pattern Matching Errors**: Non-exhaustive patterns
// 5. **Trait Errors**: Missing trait implementations

// %% [markdown]
// ### Debugging Techniques
//
// **1. println! Debugging**
// - Simple and effective for quick checks
// - Use format strings to display values
//
// **2. dbg! Macro**
// - Prints variable name and value
// - Returns the value for chaining
//
// **3. Compiler Suggestions**
// - Read the "help" section carefully
// - Follow suggested fixes
//
// **4. Incremental Compilation**
// - Comment out code to isolate issues
// - Build frequently to catch errors early

// %%
// Example: Using dbg! macro
fn debug_example() {
    let x = 5;
    let y = dbg!(x + 1);
    println!("Result: {}", y);
}

debug_example();

// %% [markdown]
// ---
//
// ## 🎯 Guided Practice
//
// ### Exercise 1: Fix Borrow Checker Error
//
// Identify and fix the ownership issue:

// %%
// TODO: Fix this code
fn borrow_error() {
    let s = String::from("hello");
    let s2 = s;
    println!("{}", s);  // Error: s was moved
}

// borrow_error();

// %% [markdown]
// ---
//
// ## 🧪 Active Recall Checkpoint
//
// 1. What does the dbg! macro do?
// 2. Name three common Rust error categories
// 3. How do you fix a "value used after move" error?
// 4. What's the difference between println! and dbg!?
// 5. How can you isolate compiler errors?

// %% [markdown]
// ---
//
// ## ✅ Expected Outcomes
//
// - [ ] Interpret compiler error messages
// - [ ] Use debugging techniques effectively
// - [ ] Fix common Rust errors independently
// - [ ] Apply debugging best practices
